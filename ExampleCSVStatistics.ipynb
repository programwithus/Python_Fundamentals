# %%
import pandas as pd

# %%
df = pd.read_csv("https://practicalprogramming.nyc3.digitaloceanspaces.com/ExampleCSV.csv", index_col = "Date")

# %%
df.head()
# Out:
#               AAPL         AMZN         IBM
# Date
# 7/2/19  202.729996  1934.310059  140.220001
# 7/3/19  204.410004  1939.000000  141.539993
# 7/5/19  204.229996  1942.910034  141.380005
# 7/8/19  200.020004  1952.319946  140.570007
# 7/9/19  201.240005  1988.300049  139.330002

# %%
df["AAPL"].plot.line(title="j")

# %%
(df/df.iloc[0]).plot();

# %%
returns = df/df.shift(1)

# %%
returns.plot.hist(alpha=0.3);

# %%
returns.describe()
# Out:
#              AAPL        AMZN         IBM
# count  253.000000  253.000000  253.000000
# mean     1.002672    1.001802    0.999714
# std      0.025496    0.019839    0.024862
# min      0.871353    0.920779    0.871493
# 25%      0.993081    0.992191    0.989784
# 50%      1.003570    1.002423    1.000334
# 75%      1.014483    1.010669    1.009622
# max      1.119808    1.073791    1.113011

# %%
returns.corr()
# Out:
#           AAPL      AMZN       IBM
# AAPL  1.000000  0.678189  0.726492
# AMZN  0.678189  1.000000  0.582438
# IBM   0.726492  0.582438  1.000000
